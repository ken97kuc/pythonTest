# %% [markdown]
# <a href="https://colab.research.google.com/github/ken97kuc/pythonTest/blob/master/horse.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import time
from tqdm.notebook import tqdm

def scrape_race_results(race_id_list, pre_race_results={}):
    race_results = pre_race_results
    for race_id in tqdm(race_id_list):
        if race_id in race_results.keys():
            continue
        try:
            time.sleep(1)
            url = "https://db.netkeiba.com/race/" + race_id
            race_results[race_id] = pd.read_html(url)[0]
        except IndexError:
            continue
        except Exception as e:
	          print(e)
	          break
        except:
	          break
    return race_results

#レースIDのリストを作る
race_id_list = []
#for place in range(1, 11, 1):
#    for kai in range(1, 6, 1):
#        for day in range(1, 13, 1):
#            for r in range(1, 13, 1):

for place in range(1, 2, 1):
    for kai in range(1, 2, 1):
        for day in range(1, 2, 1):
            for r in range(1, 2, 1):              
                race_id = "2019" + str(place).zfill(2) + str(kai).zfill(2) +\
		            str(day).zfill(2) + str(r).zfill(2)
                race_id_list.append(race_id)

#スクレイピングしてデータを保存
test3 = scrape_race_results(race_id_list)
for key in test3:
    test3[key].index = [key] * len(test3[key])
    results = pd.concat([test3[key] for key in test3], sort=False) 
    results.to_pickle('results.pickle')

# %%
import pandas as pd

url = 'https://db.netkeiba.com/race/201901010101'

a = pd.read_html(url)[0]

print(a)
# Out:
#    着順  枠番  馬番         馬名  性齢  斤量  ...     タイム     着差     単勝  人気       馬体重       調教師
# 0   1   1   1      ゴルコンダ  牡2  54  ...  1:48.3    NaN    1.4   1  518(-16)  [東] 木村哲也
# 1   2   3   3   プントファイヤー  牡2  54  ...  1:50.1      大    3.5   2   496(-8)  [東] 手塚貴久
# 2   3   4   4  ラグリマスネグラス  牡2  51  ...  1:50.9      5   46.6   6   546(+6)  [東] 藤沢和雄
# 3   4   8   9     キタノコドウ  牡2  51  ...  1:51.5  3.1/2   56.8   7   458(-8)   [東] 高木登
# 4   5   5   5   ネモフィラブルー  牡2  54  ...  1:51.7  1.1/2  140.3   9    436(0)  [西] 矢作芳人
# 5   6   8   8  マイネルラクスマン  牡2  54  ...  1:52.1  2.1/2    9.7   3   480(+8)  [東] 金成貴史
# 6   7   2   2    サンモンテベロ  牝2  54  ...  1:52.5  2.1/2  114.7   8   450(+2)  [東] 中野栄治
# 7   8   7   7   エスカレーション  牝2  54  ...  1:52.5    アタマ   26.1   5   448(-4)  [東] 高柳瑞樹
# 8   9   6   6   セイウンジュリア  牝2  54  ...  1:52.6     クビ   16.4   4    470(0)  [西] 浅見秀一
#
# [9 rows x 13 columns]

# %%
pd.read_pickle('results.pickle')
# Out:
#               着順  枠番  馬番         馬名  性齢  ...     着差     単勝 人気       馬体重       調教師
# 201901010101   1   1   1      ゴルコンダ  牡2  ...    NaN    1.4  1  518(-16)  [東] 木村哲也
# 201901010101   2   3   3   プントファイヤー  牡2  ...      大    3.5  2   496(-8)  [東] 手塚貴久
# 201901010101   3   4   4  ラグリマスネグラス  牡2  ...      5   46.6  6   546(+6)  [東] 藤沢和雄
# 201901010101   4   8   9     キタノコドウ  牡2  ...  3.1/2   56.8  7   458(-8)   [東] 高木登
# 201901010101   5   5   5   ネモフィラブルー  牡2  ...  1.1/2  140.3  9    436(0)  [西] 矢作芳人
# 201901010101   6   8   8  マイネルラクスマン  牡2  ...  2.1/2    9.7  3   480(+8)  [東] 金成貴史
# 201901010101   7   2   2    サンモンテベロ  牝2  ...  2.1/2  114.7  8   450(+2)  [東] 中野栄治
# 201901010101   8   7   7   エスカレーション  牝2  ...    アタマ   26.1  5   448(-4)  [東] 高柳瑞樹
# 201901010101   9   6   6   セイウンジュリア  牝2  ...     クビ   16.4  4    470(0)  [西] 浅見秀一
#
# [9 rows x 13 columns]
